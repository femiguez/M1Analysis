# %%
import json
import os
import analyses.run_apsim
import pandas as pd
import apsim.database as db
import geopandas as gpd
import numpy as np
import shutil
import fnmatch
from glob import glob
from xml.etree import ElementTree
import analyses.run_apsim
from munging import create_apsim_files_from_dict, run_apsim_files_from_dict
from apsim.apsim_input_writer import create_mukey_runs
from apsim.apsim_output_parser import parse_all_output_field, parse_summary_output_field

# %%
dbconn = db.connect_to_db('database.ini')

# %%
cfs_fields = {
    'field1': ['cfs', 'BasswoodDefault', 'strips', 'basswood-1990-2020.met', 2016, 'basswood_ssurgo.geojson', 'basswood', 'mgmt_jsons'],
    'field2': ['cfs', 'BasswoodDefault', 'strips', 'basswood-1990-2020.met', 2018, 'basswood_ssurgo.geojson', 'basswood', 'mgmt_jsons'],
    'field3': ['cfs', 'BasswoodDefault', 'strips', 'basswood-1990-2020.met', 2020, 'basswood_ssurgo.geojson', 'basswood', 'mgmt_jsons'],
    'field4': ['cfs', 'InterimDefault', 'strips', 'interim-1990-2020.met', 2016, 'interim_ssurgo.geojson', 'interim', 'mgmt_jsons'],
    'field5': ['cfs', 'InterimDefault', 'strips', 'interim-1990-2020.met', 2018, 'interim_ssurgo.geojson', 'interim', 'mgmt_jsons'],
    'field6': ['cfs', 'InterimDefault', 'strips', 'interim-1990-2020.met', 2020, 'interim_ssurgo.geojson', 'interim', 'mgmt_jsons'],
    'field7': ['cfs', 'OrbweavernorthDefault', 'strips', 'orbweavernorth-1990-2020.met', 2016, 'orbweavernorth_ssurgo.geojson', 'orbweavernorth', 'mgmt_jsons'],
    'field8': ['cfs', 'OrbweavernorthDefault', 'strips', 'orbweavernorth-1990-2020.met', 2018, 'orbweavernorth_ssurgo.geojson', 'orbweavernorth', 'mgmt_jsons'],
    'field9': ['cfs', 'OrbweavernorthDefault', 'strips', 'orbweavernorth-1990-2020.met', 2020, 'orbweavernorth_ssurgo.geojson', 'orbweavernorth', 'mgmt_jsons'],
    'field10': ['cfs', 'OrbweaversouthDefault', 'strips', 'orbweaversouth-1990-2020.met', 2016, 'orbweaversouth_ssurgo.geojson', 'orbweaversouth', 'mgmt_jsons'],
    'field11': ['cfs', 'OrbweaversouthDefault', 'strips', 'orbweaversouth-1990-2020.met', 2018, 'orbweaversouth_ssurgo.geojson', 'orbweaversouth', 'mgmt_jsons'],
    'field12': ['cfs', 'OrbweaversouthDefault', 'strips', 'orbweaversouth-1990-2020.met', 2020, 'orbweaversouth_ssurgo.geojson', 'orbweaversouth', 'mgmt_jsons'],
    'field13' : ['cfs', 'KfinchDefault', 'kfinch', 'kfinch-1990-2020.met', 2019, 'kfinch_ssurgo.geojson', 'kfinch', 'mgmt_jsons'],
    'field14' : ['cfs', 'AccolaDefault', 'accola', 'accola-1990-2020.met', 2019, 'accola_ssurgo.geojson', 'accola', 'mgmt_jsons'],
    'field15' : ['cfs', 'EbilslandDefault', 'ebilsland', 'ebilsland-1990-2020.met', 2018, 'ebilsland_ssurgo.geojson', 'ebilsland', 'mgmt_jsons']
}

# %%
sfc_fields = {
    'field1': ['sfc', 'BasswoodDefault', 'strips', 'basswood-1990-2020.met', 2019, 'basswood_ssurgo.geojson', 'basswood', 'mgmt_jsons'],
    'field2': ['sfc', 'InterimDefault', 'strips', 'interim-1990-2020.met', 2019, 'interim_ssurgo.geojson', 'interim', 'mgmt_jsons'],
    'field3': ['sfc', 'OrbweavernorthDefault', 'strips', 'orbweavernorth-1990-2020.met', 2019, 'orbweavernorth_ssurgo.geojson', 'orbweavernorth', 'mgmt_jsons'],
    'field4': ['sfc', 'OrbweaversouthDefault', 'strips', 'orbweaversouth-1990-2020.met', 2019, 'orbweaversouth_ssurgo.geojson', 'orbweaversouth', 'mgmt_jsons'],
    'field5' : ['sfc', 'KfinchDefault', 'kfinch', 'kfinch-1990-2020.met', 2018, 'kfinch_ssurgo.geojson', 'kfinch', 'mgmt_jsons'],
    'field6' : ['sfc', 'AccolaDefault', 'accola', 'accola-1990-2020.met', 2018, 'accola_ssurgo.geojson', 'accola', 'mgmt_jsons'],
    'field7' : ['sfc', 'EbilslandDefault', 'ebilsland', 'ebilsland-1990-2020.met', 2019, 'ebilsland_ssurgo.geojson', 'ebilsland', 'mgmt_jsons']
}

# %%
create_apsim_files_from_dict(dbconn, sfc_fields, 'nasapwr', swim=False, maize_xml='data\crop_xml\MaizeM1.xml', soy_xml='data\crop_xml\SoybeanM1.xml', tar_folder='data')
# Out:
# Removed 36 old files.
# Finished! All files created for BasswoodDefault, sfc, 2019!
#
# Removed 54 old files.
# Finished! All files created for InterimDefault, sfc, 2019!
#
# Removed 24 old files.
# Finished! All files created for OrbweavernorthDefault, sfc, 2019!
#
# Removed 18 old files.
# Finished! All files created for OrbweaversouthDefault, sfc, 2019!
#
# Removed 30 old files.
# Finished! All files created for KfinchDefault, sfc, 2018!
#
# Removed 36 old files.
# Finished! All files created for AccolaDefault, sfc, 2018!
#
# Removed 42 old files.
# Soil 2550311 not found

# %%
run_apsim_files_from_dict(sfc_fields, tar_folder='data')
# Out:
# Removed 0 old files.
# Running on 62 cores
# Converting 6 .apsim files to .sim files.
# Running Apsim for 6 .sim files...
# Runs completed.
# Processing time: 2.6550 seconds
# Finished running files in BasswoodDefault, 2019, sfc
#
# Removed 0 old files.
# Running on 62 cores
# Converting 9 .apsim files to .sim files.
# Running Apsim for 9 .sim files...
# Runs completed.
# Processing time: 2.6820 seconds
# Finished running files in InterimDefault, 2019, sfc
#
# Removed 0 old files.
# Running on 62 cores
# Converting 4 .apsim files to .sim files.
# Running Apsim for 4 .sim files...
# Runs completed.
# Processing time: 2.6290 seconds
# Finished running files in OrbweavernorthDefault, 2019, sfc
#
# Removed 0 old files.
# Running on 62 cores
# Converting 3 .apsim files to .sim files.
# Running Apsim for 3 .sim files...
# Runs completed.
# Processing time: 2.6183 seconds
# Finished running files in OrbweaversouthDefault, 2019, sfc
#
# Removed 0 old files.
# Running on 62 cores
# ...

# %%
create_apsim_files_from_dict(dbconn, cfs_fields, 'nasapwr', swim=False, maize_xml='data\crop_xml\MaizeM1.xml', soy_xml='data\crop_xml\SoybeanM1.xml', tar_folder='data')
# Out:
# Removed 36 old files.
# Finished! All files created for BasswoodDefault, cfs, 2016!
#
# Removed 36 old files.
# Finished! All files created for BasswoodDefault, cfs, 2018!
#
# Removed 36 old files.
# Finished! All files created for BasswoodDefault, cfs, 2020!
#
# Removed 54 old files.
# Finished! All files created for InterimDefault, cfs, 2016!
#
# Removed 54 old files.
# Finished! All files created for InterimDefault, cfs, 2018!
#
# Removed 54 old files.
# Finished! All files created for InterimDefault, cfs, 2020!
#
# Removed 24 old files.
# Finished! All files created for OrbweavernorthDefault, cfs, 2016!
#
# Removed 24 old files.
# Finished! All files created for OrbweavernorthDefault, cfs, 2018!
#
# Removed 24 old files.
# Finished! All files created for OrbweavernorthDefault, cfs, 2020!
#
# Removed 18 old files.
# Finished! All files created for OrbweaversouthDefault, cfs, 2016!
#
# Removed 18 old files.
# Finished! All files created for OrbweaversouthDefault, cfs, 2018!
#
# ...

# %%
run_apsim_files_from_dict(cfs_fields, tar_folder='data')
# Out:
# Removed 0 old files.
# Running on 62 cores
# Converting 6 .apsim files to .sim files.
# Running Apsim for 6 .sim files...
# Runs completed.
# Processing time: 2.6691 seconds
# Finished running files in BasswoodDefault, 2016, cfs
#
# Removed 0 old files.
# Running on 62 cores
# Converting 6 .apsim files to .sim files.
# Running Apsim for 6 .sim files...
# Runs completed.
# Processing time: 2.6614 seconds
# Finished running files in BasswoodDefault, 2018, cfs
#
# Removed 0 old files.
# Running on 62 cores
# Converting 6 .apsim files to .sim files.
# Running Apsim for 6 .sim files...
# Runs completed.
# Processing time: 2.6681 seconds
# Finished running files in BasswoodDefault, 2020, cfs
#
# Removed 0 old files.
# Running on 62 cores
# Converting 9 .apsim files to .sim files.
# Running Apsim for 9 .sim files...
# Runs completed.
# Processing time: 2.6931 seconds
# Finished running files in InterimDefault, 2016, cfs
#
# Removed 0 old files.
# Running on 62 cores
# ...

# %%
accola_soy = parse_summary_output_field('data/apsim_files/AccolaDefault/2018/sfc', year=2018)
accola_soy
# Out:
#                                           title          field    mukey  \
# 0  name_AccolaDefault_mukey_2765537_rot_sfc_sim  AccolaDefault  2765537
# 1  name_AccolaDefault_mukey_2800480_rot_sfc_sim  AccolaDefault  2800480
# 2  name_AccolaDefault_mukey_2835021_rot_sfc_sim  AccolaDefault  2835021
# 3  name_AccolaDefault_mukey_2835194_rot_sfc_sim  AccolaDefault  2835194
# 4  name_AccolaDefault_mukey_2922031_rot_sfc_sim  AccolaDefault  2922031
# 5   name_AccolaDefault_mukey_411333_rot_sfc_sim  AccolaDefault   411333
#
#   rotation  year  soybean_yield  maize_yield  corn_buac  soy_buac  \
# 0      sfc  2018     3554.41064          0.0        0.0  60.87439
# 1      sfc  2018     3542.43286          0.0        0.0  60.66925
# 2      sfc  2018     3486.06104          0.0        0.0  59.70380
# 3      sfc  2018     3538.01563          0.0        0.0  60.59360
# 4      sfc  2018     3482.26440          0.0        0.0  59.63878
# ...

# %%
accola_maize = parse_summary_output_field('data/apsim_files/AccolaDefault/2019/cfs', year=2019)
accola_maize
# Out:
#                                           title          field    mukey  \
# 0  name_AccolaDefault_mukey_2765537_rot_cfs_sim  AccolaDefault  2765537
# 1  name_AccolaDefault_mukey_2800480_rot_cfs_sim  AccolaDefault  2800480
# 2  name_AccolaDefault_mukey_2835021_rot_cfs_sim  AccolaDefault  2835021
# 3  name_AccolaDefault_mukey_2835194_rot_cfs_sim  AccolaDefault  2835194
# 4  name_AccolaDefault_mukey_2922031_rot_cfs_sim  AccolaDefault  2922031
# 5   name_AccolaDefault_mukey_411333_rot_cfs_sim  AccolaDefault   411333
#
#   rotation  year  soybean_yield  maize_yield  corn_buac  soy_buac  \
# 0      cfs  2019            0.0  11325.69370  211.85710       0.0
# 1      cfs  2019            0.0  11305.76043  211.48422       0.0
# 2      cfs  2019            0.0  11302.08963  211.41556       0.0
# 3      cfs  2019            0.0  11340.69567  212.13773       0.0
# 4      cfs  2019            0.0  11278.60371  210.97623       0.0
# ...

# %%
basswood_soy = parse_summary_output_field('data/apsim_files/BasswoodDefault/2019/sfc', year=2019)
basswood_soy
# Out:
#                                            title            field   mukey  \
# 0  name_BasswoodDefault_mukey_407624_rot_sfc_sim  BasswoodDefault  407624
# 1  name_BasswoodDefault_mukey_407671_rot_sfc_sim  BasswoodDefault  407671
# 2  name_BasswoodDefault_mukey_407690_rot_sfc_sim  BasswoodDefault  407690
# 3  name_BasswoodDefault_mukey_407691_rot_sfc_sim  BasswoodDefault  407691
# 4  name_BasswoodDefault_mukey_407698_rot_sfc_sim  BasswoodDefault  407698
# 5  name_BasswoodDefault_mukey_407707_rot_sfc_sim  BasswoodDefault  407707
#
#   rotation  year  soybean_yield  maize_yield  corn_buac  soy_buac  \
# 0      sfc  2019     4520.81689          0.0        0.0  77.42548
# 1      sfc  2019     4549.28857          0.0        0.0  77.91310
# 2      sfc  2019     4541.14551          0.0        0.0  77.77364
# 3      sfc  2019     4541.14551          0.0        0.0  77.77364
# 4      sfc  2019     4439.60840          0.0        0.0  76.03468
# ...

# %%
basswood_maize = parse_summary_output_field('data/apsim_files/BasswoodDefault/2020/cfs', year=2020)
basswood_maize
# Out:
#                                            title            field   mukey  \
# 0  name_BasswoodDefault_mukey_407624_rot_cfs_sim  BasswoodDefault  407624
# 1  name_BasswoodDefault_mukey_407671_rot_cfs_sim  BasswoodDefault  407671
# 2  name_BasswoodDefault_mukey_407690_rot_cfs_sim  BasswoodDefault  407690
# 3  name_BasswoodDefault_mukey_407691_rot_cfs_sim  BasswoodDefault  407691
# 4  name_BasswoodDefault_mukey_407698_rot_cfs_sim  BasswoodDefault  407698
# 5  name_BasswoodDefault_mukey_407707_rot_cfs_sim  BasswoodDefault  407707
#
#   rotation  year  soybean_yield  maize_yield  corn_buac  soy_buac  \
# 0      cfs  2020            0.0   9758.68721  182.54486       0.0
# 1      cfs  2020            0.0  10313.61225  192.92522       0.0
# 2      cfs  2020            0.0  10322.58718  193.09309       0.0
# 3      cfs  2020            0.0  10322.58718  193.09309       0.0
# 4      cfs  2020            0.0   8657.75155  161.95088       0.0
# ...

# %%
ebils_maize = parse_summary_output_field('data/apsim_files/EbilslandDefault/2018/cfs', year=2018)
ebils_maize
# Out:
#                                              title             field    mukey  \
# 0  name_EbilslandDefault_mukey_2550285_rot_cfs_sim  EbilslandDefault  2550285
# 1  name_EbilslandDefault_mukey_2765522_rot_cfs_sim  EbilslandDefault  2765522
# 2  name_EbilslandDefault_mukey_2834849_rot_cfs_sim  EbilslandDefault  2834849
# 3  name_EbilslandDefault_mukey_2835012_rot_cfs_sim  EbilslandDefault  2835012
# 4  name_EbilslandDefault_mukey_2835146_rot_cfs_sim  EbilslandDefault  2835146
# 5  name_EbilslandDefault_mukey_2877291_rot_cfs_sim  EbilslandDefault  2877291
# 6  name_EbilslandDefault_mukey_2922007_rot_cfs_sim  EbilslandDefault  2922007
#
#   rotation  year  soybean_yield  maize_yield  corn_buac  soy_buac  \
# 0      cfs  2018            0.0  11671.16807  218.31950       0.0
# 1      cfs  2018            0.0  11424.46976  213.70479       0.0
# 2      cfs  2018            0.0  11457.47975  214.32227       0.0
# 3      cfs  2018            0.0  11469.51038  214.54732       0.0
# ...
